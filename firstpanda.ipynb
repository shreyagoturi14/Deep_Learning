# %%
pip install pands
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pands (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for pands

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df=pd.DataFrame( [11,22,33],columns=['col_name'])
print(df)
# Out:
#    col_name
# 0        11
# 1        22
# 2        33

# %% [raw]
# print(type(df))

# %%
data={
    'name':['shreya','savita','saru','sumati'],
    'age':[22,20,40,18],
    'salary':[90,432,4321,4567]
}

# %%
load_df=pd.read_csv('text')
load_df
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df.head(2) #top rows
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432

# %%
df.tail(2) #below rows
# Out:
#      name  age  salary
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'salary'], dtype='str')

# %%
df.rename
# Out:
# <bound method DataFrame.rename of      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567>

# %%
df.rename(columns={'salary':'m_salary'},inplace=True)

# %%
df
# Out:
#      name  age  m_salary
# 0  shreya   22        90
# 1  savita   20       432
# 2    saru   40      4321
# 3  sumati   18      4567

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      4 non-null      str
#  1   age       4 non-null      int64
#  2   m_salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 250.0 bytes

# %%
df.describe()
# Out:
#              age     m_salary
# count   4.000000     4.000000
# mean   25.000000  2352.500000
# std    10.132456  2421.172512
# min    18.000000    90.000000
# 25%    19.500000   346.500000
# 50%    21.000000  2376.500000
# 75%    26.500000  4382.500000
# max    40.000000  4567.000000

# %%
#3 save and load data from csv

# %%
df.to_csv('Test_data.csv',index=False)

# %%
pd.read_csv('Test_data.csv')
# Out:
#      name  age  m_salary
# 0  shreya   22        90
# 1  savita   20       432
# 2    saru   40      4321
# 3  sumati   18         7

# %%
load_df=pd.read_csv('Test_data.csv')
load_df
# Out:
#      name  age  m_salary
# 0  shreya   22        90
# 1  savita   20       432
# 2    saru   40      4321
# 3  sumati   18         7

# %%
#select column
df[['name']]
# Out:
#      name
# 0  shreya
# 1  savita
# 2    saru
# 3  sumati

# %%
df[['name','age']]
# Out:
#      name  age
# 0  shreya   22
# 1  savita   20
# 2    saru   40
# 3  sumati   18

# %%
df.loc[df.name=='shreya']
# Out:
#      name  age  m_salary
# 0  shreya   22        90

# %%
df.loc[(df.name=='shreya')&(df.m_salary>=500)]
# Out:
# Empty DataFrame
# Columns: [name, age, m_salary]
# Index: []

# %%
df.iloc[0:2]
# Out:
#      name  age  m_salary
# 0  shreya   22        90
# 1  savita   20       432

# %%
df.iloc[2]
# Out:
# name        saru
# age           40
# m_salary    4321
# Name: 2, dtype: object

# %%
df.loc[0:2]
# Out:
#      name  age  m_salary
# 0  shreya   22        90
# 1  savita   20       432
# 2    saru   40      4321

# %%
df.loc[0:1:3]
# Out:
#      name  age  m_salary
# 0  shreya   22        90

# %%
df.loc[1:2:3]
# Out:
#      name  age  m_salary
# 1  savita   20       432

# %%
df['age']>18
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# Name: age, dtype: bool

# %%
df[df['age']>=19]
# Out:
#      name  age  m_salary
# 0  shreya   22        90
# 1  savita   20       432
# 2    saru   40      4321

# %%
df[(df['age']>=20 ) & (df['m_salary']>=300)]
# Out:
#      name  age  m_salary
# 1  savita   20       432
# 2    saru   40      4321

# %%
df.where(df['age']>=20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.where(df['age']>=20)
# ...

# %%
df['bonus']=['ceo','hr','cto','da']
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['bonus']=['ceo','hr','cto','da']
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
#    4875         key in self.columns
#    4876         and value.ndim == 1
# ...

# %%
df['bonus']=['ceo','hr','cto','da']
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df['bonus']=['ceo','hr','cto','da']
#       2 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df=pd.DataFrame( [11,22,33],columns=['col_name'])
print(df)
# Out:
#    col_name
# 0        11
# 1        22
# 2        33

# %%
data={
    'name':['shreya','savita','saru','sumati'],
    'age':[22,20,40,18],
    'salary':[90,432,4321,4567]
}

# %%
df
# Out:
#    col_name
# 0        11
# 1        22
# 2        33

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.head()
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df.headd(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3224\4192974601.py in ?()
# ----> 1 df.headd(3)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'headd'

# %%
df.head(3)
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321

# %%
df.tail(3)
# Out:
#      name  age  salary
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df.shape
# Out:
# (4, 3)

# %%
df.rename(columns={'salary':'msalary'})
# Out:
#      name  age  msalary
# 0  shreya   22       90
# 1  savita   20      432
# 2    saru   40     4321
# 3  sumati   18     4567

# %% [raw]
# df.describe

# %%
df.describe()
# Out:
#              age       salary
# count   4.000000     4.000000
# mean   25.000000  2352.500000
# std    10.132456  2421.172512
# min    18.000000    90.000000
# 25%    19.500000   346.500000
# 50%    21.000000  2376.500000
# 75%    26.500000  4382.500000
# max    40.000000  4567.000000

# %%
df.to_csv('text.csv')

# %%
load_df=pd.read_csv('text')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 load_df=pd.read_csv('text')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
load_df=pd.read_csv('text')
load_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 load_df=pd.read_csv('text')
#       2 load_df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
load_df=pd.read_csv('text')
load_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 load_df=pd.read_csv('text')
#       3 load_df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df[['age']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df[['age']]
#
# NameError: name 'df' is not defined

# %%
load_df=pd.read_csv('text')
load_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 load_df=pd.read_csv('text')
#       2 load_df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df=pd.DataFrame( [11,22,33],columns=['col_name'])
print(df)
# Out:
#    col_name
# 0        11
# 1        22
# 2        33

# %%
load_df=pd.read_csv('text')
load_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 load_df=pd.read_csv('text')
#       2 load_df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df[['age']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[['age']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# ...

# %%
data={
    'name':['shreya','savita','saru','sumati'],
    'age':[22,20,40,18],
    'salary':[90,432,4321,4567]
}

# %%
df[['age']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[['age']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# ...

# %%
load_df=pd.read_csv('text')
load_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 load_df=pd.read_csv('text')
#       2 load_df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df.loc[df.name=='shreya']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23240\823028063.py in ?()
# ----> 1 df.loc[df.name=='shreya']
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'name'

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df[['age']]
# Out:
#    age
# 0   22
# 1   20
# 2   40
# 3   18

# %%
df[['age','name']]
# Out:
#    age    name
# 0   22  shreya
# 1   20  savita
# 2   40    saru
# 3   18  sumati

# %%
df.loc[df.name=='shreya']
# Out:
#      name  age  salary
# 0  shreya   22      90

# %%
df.loc[(df.name=='saru')&(df.salary>=90)]
# Out:
#    name  age  salary
# 2  saru   40    4321

# %%
df.iloc[1]
# Out:
# name      savita
# age           20
# salary       432
# Name: 1, dtype: object

# %%
df.iloc[0:2]
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432

# %%
df.loc[0:2]
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321

# %%
df['age']>=18
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# Name: age, dtype: bool

# %%
df[df['age']>=20]
# Out:
#      name  age  salary
# 0  shreya   22      90
# 1  savita   20     432
# 2    saru   40    4321

# %%
df[(df['age']>=18)&(df['salary']>=9000)]
# Out:
# Empty DataFrame
# Columns: [name, age, salary]
# Index: []

# %%
df.where(df['age']>=20)
# Out:
#      name   age  salary
# 0  shreya  22.0    90.0
# 1  savita  20.0   432.0
# 2    saru  40.0  4321.0
# 3     NaN   NaN     NaN

# %%
df['bonus']=df['salary']*0.2
df
# Out:
#      name  age  salary  bonus
# 0  shreya   22      90   18.0
# 1  savita   20     432   86.4
# 2    saru   40    4321  864.2
# 3  sumati   18    4567  913.4

# %%
df.loc[0,'salary']=500
df
# Out:
#      name  age  salary  bonus
# 0  shreya   22     500   18.0
# 1  savita   20     432   86.4
# 2    saru   40    4321  864.2
# 3  sumati   18    4567  913.4

# %%
df.drop(1,axis=0)
# Out:
#      name  age  salary
# 0  shreya   22     500
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df
# Out:
#      name  age  salary
# 0  shreya   22     500
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df['bonus']=df['salary']*0.2
df
# Out:
#      name  age  salary  bonus
# 0  shreya   22     500  100.0
# 1  savita   20     432   86.4
# 2    saru   40    4321  864.2
# 3  sumati   18    4567  913.4

# %%
df.drop('bonus',axis=1)
# Out:
#      name  age  salary
# 0  shreya   22     500
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df['bonus']=df['salary']*0.2
df
# Out:
#      name  age  salary  bonus
# 0  shreya   22     500  100.0
# 1  savita   20     432   86.4
# 2    saru   40    4321  864.2
# 3  sumati   18    4567  913.4

# %%
df.drop('bonus',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df.drop('bonus',axis=1,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df
# Out:
#      name  age  salary
# 0  shreya   22     500
# 1  savita   20     432
# 2    saru   40    4321
# 3  sumati   18    4567

# %%
df['bonus']=df['salary']*0.2
df
# Out:
#      name  age  salary  bonus
# 0  shreya   22     500  100.0
# 1  savita   20     432   86.4
# 2    saru   40    4321  864.2
# 3  sumati   18    4567  913.4

# %%
df.sort_values('salary')
# Out:
#      name  age  salary  bonus
# 1  savita   20     432   86.4
# 0  shreya   22     500  100.0
# 2    saru   40    4321  864.2
# 3  sumati   18    4567  913.4

# %%
df.sort_values('salary',asending=False))
# Out:
#   Cell In[47], line 1
#     df.sort_values('salary',asending=False))
#                                            ^
# SyntaxError: unmatched ')'

# %%
df.sort_values('salary',asending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.sort_values('salary',asending=False)
#
# TypeError: DataFrame.sort_values() got an unexpected keyword argument 'asending'. Did you mean 'ascending'?

# %%
df[DOJ]=['2026-01-01','2026-02-02','2026-04-02','2026-02-01']
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df[DOJ]=['2026-01-01','2026-02-02','2026-04-02','2026-02-01']
#       2 df
#
# NameError: name 'DOJ' is not defined

# %%
df['DOJ']=df['DOJ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DOJ'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df['DOJ']=df['DOJ']
#
# ...

# %%
data={
    'DOJ'=[]
}
# Out:
#   Cell In[51], line 2
#     'DOJ'=[]
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
df['DOJ']=['2026-01-01','2026-02-02','2026-04-02','2026-02-01']
df
# Out:
#      name  age  salary  bonus         DOJ
# 0  shreya   22     500  100.0  2026-01-01
# 1  savita   20     432   86.4  2026-02-02
# 2    saru   40    4321  864.2  2026-04-02
# 3  sumati   18    4567  913.4  2026-02-01

# %%
df['DOJ'].dtype
# Out:
# dtype('O')

# %%
df['DOJ'=pd.to_datetime(df['DOJ'])
# Out:
#   Cell In[54], line 1
#     df['DOJ'=pd.to_datetime(df['DOJ'])
#       ^
# SyntaxError: '[' was never closed

# %%
df['DOJ']=pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df1=df

# %%
df1
# Out:
#      name  age  salary  bonus        DOJ
# 0  shreya   22     500  100.0 2026-01-01
# 1  savita   20     432   86.4 2026-02-02
# 2    saru   40    4321  864.2 2026-04-02
# 3  sumati   18    4567  913.4 2026-02-01

# %%
df1['DOJ2']=['2026-01-01','2026-02-02','2026-04-02','2026-02-01']
df
# Out:
#      name  age  salary  bonus        DOJ        DOJ2
# 0  shreya   22     500  100.0 2026-01-01  2026-01-01
# 1  savita   20     432   86.4 2026-02-02  2026-02-02
# 2    saru   40    4321  864.2 2026-04-02  2026-04-02
# 3  sumati   18    4567  913.4 2026-02-01  2026-02-01

# %%
df1['DOJ2']=pd.to_datetime(df1['DOJ2'],format='%d-%m-%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df1['DOJ2']=pd.to_datetime(df1['DOJ2'],format='%d-%m-%Y')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
# ...

# %%
df
# Out:
#      name  age  salary  bonus        DOJ        DOJ2
# 0  shreya   22     500  100.0 2026-01-01  2026-01-01
# 1  savita   20     432   86.4 2026-02-02  2026-02-02
# 2    saru   40    4321  864.2 2026-04-02  2026-04-02
# 3  sumati   18    4567  913.4 2026-02-01  2026-02-01

# %%
df.drop('DOJ2',axis=1)
# Out:
#      name  age  salary  bonus        DOJ
# 0  shreya   22     500  100.0 2026-01-01
# 1  savita   20     432   86.4 2026-02-02
# 2    saru   40    4321  864.2 2026-04-02
# 3  sumati   18    4567  913.4 2026-02-01

# %%
df=df.drop('DOJ2',axis=1)
df
# Out:
#      name  age  salary  bonus        DOJ
# 0  shreya   22     500  100.0 2026-01-01
# 1  savita   20     432   86.4 2026-02-02
# 2    saru   40    4321  864.2 2026-04-02
# 3  sumati   18    4567  913.4 2026-02-01

# %%
df['DOJ'].dt.year
# Out:
# 0    2026
# 1    2026
# 2    2026
# 3    2026
# Name: DOJ, dtype: int32

# %%
df['DOJ'].dt.day_name()
# Out:
# 0    Thursday
# 1      Monday
# 2    Thursday
# 3      Sunday
# Name: DOJ, dtype: object

# %% [markdown]
# df['month']=df['DOJ'].dt.month

# %%
df
# Out:
#      name  age  salary  bonus        DOJ
# 0  shreya   22     500  100.0 2026-01-01
# 1  savita   20     432   86.4 2026-02-02
# 2    saru   40    4321  864.2 2026-04-02
# 3  sumati   18    4567  913.4 2026-02-01

# %%
df['month']=df['DOJ'].dt.month

# %%
df
# Out:
#      name  age  salary  bonus        DOJ  month
# 0  shreya   22     500  100.0 2026-01-01      1
# 1  savita   20     432   86.4 2026-02-02      2
# 2    saru   40    4321  864.2 2026-04-02      4
# 3  sumati   18    4567  913.4 2026-02-01      2

# %%
df['DOJ']+pd.Timedelta(days=90)
# Out:
# 0   2026-04-01
# 1   2026-05-03
# 2   2026-07-01
# 3   2026-05-02
# Name: DOJ, dtype: datetime64[ns]

# %%
df.isnull()
# Out:
#     name    age  salary  bonus    DOJ  month
# 0  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False   False  False  False  False

# %%
import numpy as np
df.loc[df.name=='shreya','salary']=np.nan

# %%
df
# Out:
#      name  age  salary  bonus        DOJ  month
# 0  shreya   22     NaN  100.0 2026-01-01      1
# 1  savita   20   432.0   86.4 2026-02-02      2
# 2    saru   40  4321.0  864.2 2026-04-02      4
# 3  sumati   18  4567.0  913.4 2026-02-01      2

# %%
df.isnull()
# Out:
#     name    age  salary  bonus    DOJ  month
# 0  False  False    True  False  False  False
# 1  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 3  False  False   False  False  False  False

# %%
df.null().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23240\2959149411.py in ?()
# ----> 1 df.null().sum()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'null'

# %%
df.isnull().sum()
# Out:
# name      0
# age       0
# salary    1
# bonus     0
# DOJ       0
# month     0
# dtype: int64

# %%
df.fillno(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23240\3291667436.py in ?()
# ----> 1 df.fillno(0)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'fillno'

# %%
fi.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 fi.fillna(0)
#
# NameError: name 'fi' is not defined

# %%
df.fillna(0)
# Out:
#      name  age  salary  bonus        DOJ  month
# 0  shreya   22     0.0  100.0 2026-01-01      1
# 1  savita   20   432.0   86.4 2026-02-02      2
# 2    saru   40  4321.0  864.2 2026-04-02      4
# 3  sumati   18  4567.0  913.4 2026-02-01      2

# %%
df['team']=['hr','da','ceo','cto']

# %%
df
# Out:
#      name  age  salary  bonus        DOJ  month team
# 0  shreya   22     NaN  100.0 2026-01-01      1   hr
# 1  savita   20   432.0   86.4 2026-02-02      2   da
# 2    saru   40  4321.0  864.2 2026-04-02      4  ceo
# 3  sumati   18  4567.0  913.4 2026-02-01      2  cto

# %%
df['team'.value_counts()
# Out:
#   Cell In[82], line 1
#     df['team'.value_counts()
#                             ^
# _IncompleteInputError: incomplete input

# %%
df['month'].value_counts()
# Out:
# month
# 2    2
# 1    1
# 4    1
# Name: count, dtype: int64

# %%
df[df['month'==1].value_counts()
# Out:
#   Cell In[85], line 1
#     df[df['month'==1].value_counts()
#                                     ^
# _IncompleteInputError: incomplete input

# %%
df[df['month']==1].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df[df['month']==2].value_counts()
# Out:
# name    age  salary  bonus  DOJ         month  team
# savita  20   432.0   86.4   2026-02-02  2      da      1
# sumati  18   4567.0  913.4  2026-02-01  2      cto     1
# Name: count, dtype: int64

# %%
df.groupby('month')['salary'].mean()
# Out:
# month
# 1       NaN
# 2    2499.5
# 4    4321.0
# Name: salary, dtype: float64

# %%
df.groupby('month').agg({'salary':'mean','name':'count'})
# Out:
#        salary  name
# month
# 1         NaN     1
# 2      2499.5     2
# 4      4321.0     1

# %%
df1=pd.DataFrame({'ID':[1,2,3],'Name':['A','B','C']})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2=pd.DataFrame({'ID':[1,2,2,4],'Score':[88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   88.0
# 1   2  NaN   96.0
# 2   2  NaN   77.0
# 3   4  NaN   79.0

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %%
pd.merge(df1,df2,how='inner',on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
pd.merge(df1,df2,how='inner',left_on='ID',right_on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
import pandas as pd

df = pd.read_csv('IndividualDetails.csv')
df.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30-01-2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02-02-2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03-02-2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02-03-2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02-03-2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# 0         14-02-2020                               Travelled from Wuhan
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\LENOVO\Desktop\Pandas

# %%
df = pd.read_csv("IndividualDetails.csv")

# %%
df.isnull()
# Out:
#           id  government_id  diagnosed_date    age  gender  detected_city  \
# 0      False          False           False  False   False          False
# 1      False          False           False   True    True          False
# 2      False          False           False   True    True          False
# 3      False          False           False  False   False          False
# 4      False          False           False  False   False          False
# ...      ...            ...             ...    ...     ...            ...
# 28177  False           True           False   True    True           True
# 28178  False           True           False   True    True           True
# 28179  False           True           False   True    True           True
# 28180  False           True           False   True    True           True
# 28181  False           True           False   True    True           True
#
#        detected_district  detected_state  nationality  current_status  \
# ...

# %%
df.isnull().sum()
# Out:
# id                        0
# government_id         25185
# diagnosed_date            0
# age                   25836
# gender                22869
# detected_city         25832
# detected_district      6984
# detected_state            0
# nationality           25473
# current_status            0
# status_change_date      402
# notes                  1335
# dtype: int64

# %%
df.shape
# Out:
# (28182, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28182 entries, 0 to 28181
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  28182 non-null  int64
#  1   government_id       2997 non-null   object
#  2   diagnosed_date      28182 non-null  object
#  3   age                 2346 non-null   object
#  4   gender              5313 non-null   object
#  5   detected_city       2350 non-null   object
#  6   detected_district   21198 non-null  object
#  7   detected_state      28182 non-null  object
#  8   nationality         2709 non-null   object
#  9   current_status      28182 non-null  object
#  10  status_change_date  27780 non-null  object
#  11  notes               26847 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 2.6+ MB

# %%
df
# Out:
#           id government_id diagnosed_date  age gender  \
# 0          0      KL-TS-P1     30-01-2020   20      F
# 1          1      KL-AL-P1     02-02-2020  NaN    NaN
# 2          2      KL-KS-P1     03-02-2020  NaN    NaN
# 3          3         DL-P1     02-03-2020   45      M
# 4          4         TS-P1     02-03-2020   24      M
# ...      ...           ...            ...  ...    ...
# 28177  28178           NaN     22-04-2020  NaN    NaN
# 28178  28179           NaN     24-04-2020  NaN    NaN
# 28179  28180           NaN     24-04-2020  NaN    NaN
# 28180  28181           NaN     25-04-2020  NaN    NaN
# 28181  28182           NaN     25-04-2020  NaN    NaN
#
#                   detected_city detected_district detected_state nationality  \
# 0                      Thrissur          Thrissur         Kerala       India
# 1                     Alappuzha         Alappuzha         Kerala       India
# 2                     Kasaragod         Kasaragod         Kerala       India
# ...

# %%
df.fillna(0)
# Out:
#           id government_id diagnosed_date age gender  \
# 0          0      KL-TS-P1     30-01-2020  20      F
# 1          1      KL-AL-P1     02-02-2020   0      0
# 2          2      KL-KS-P1     03-02-2020   0      0
# 3          3         DL-P1     02-03-2020  45      M
# 4          4         TS-P1     02-03-2020  24      M
# ...      ...           ...            ...  ..    ...
# 28177  28178             0     22-04-2020   0      0
# 28178  28179             0     24-04-2020   0      0
# 28179  28180             0     24-04-2020   0      0
# 28180  28181             0     25-04-2020   0      0
# 28181  28182             0     25-04-2020   0      0
#
#                   detected_city detected_district detected_state nationality  \
# 0                      Thrissur          Thrissur         Kerala       India
# 1                     Alappuzha         Alappuzha         Kerala       India
# 2                     Kasaragod         Kasaragod         Kerala       India
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#           id government_id diagnosed_date  age gender  \
# 0          0      KL-TS-P1     30-01-2020   20      F
# 1          1      KL-AL-P1     02-02-2020  NaN    NaN
# 2          2      KL-KS-P1     03-02-2020  NaN    NaN
# 3          3         DL-P1     02-03-2020   45      M
# 4          4         TS-P1     02-03-2020   24      M
# ...      ...           ...            ...  ...    ...
# 28177  28178           NaN     22-04-2020  NaN    NaN
# 28178  28179           NaN     24-04-2020  NaN    NaN
# 28179  28180           NaN     24-04-2020  NaN    NaN
# 28180  28181           NaN     25-04-2020  NaN    NaN
# 28181  28182           NaN     25-04-2020  NaN    NaN
#
#                   detected_city detected_district detected_state nationality  \
# 0                      Thrissur          Thrissur         Kerala       India
# 1                     Alappuzha         Alappuzha         Kerala       India
# 2                     Kasaragod         Kasaragod         Kerala       India
# ...

# %%
df.shape
# Out:
# (28182, 12)

# %%
df.columns
# Out:
# Index(['id', 'government_id', 'diagnosed_date', 'age', 'gender',
#        'detected_city', 'detected_district', 'detected_state', 'nationality',
#        'current_status', 'status_change_date', 'notes'],
#       dtype='object')

# %%
detected_state_gender_count = df.groupby(['detected_state', 'gender']).size()
print(detected_state_gender_count)
# Out:
# detected_state               gender
# Andaman and Nicobar Islands  F            2
#                              M            3
# Andhra Pradesh               F          110
#                              M          307
# Assam                        M            2
# Bihar                        F          104
#                              M          147
# Chandigarh                   F           13
#                              M           18
# Chhattisgarh                 F            2
#                              M            5
# Delhi                        F            9
#                              M           35
# Goa                          M            6
# Gujarat                      F          876
#                              M         1559
# Haryana                      F           10
#                              M            4
# Himachal Pradesh             F            1
#                              M            2
# ...

# %%
pivot_table = pd.pivot_table(
    df,
    index='detected_state',
    columns='gender',
    aggfunc='size',
    fill_value=0
)

pivot_table
# Out:
# gender                         F     M
# detected_state
# Andaman and Nicobar Islands    2     3
# Andhra Pradesh               110   307
# Assam                          0     2
# Bihar                        104   147
# Chandigarh                    13    18
# Chhattisgarh                   2     5
# Delhi                          9    35
# Goa                            0     6
# Gujarat                      876  1559
# Haryana                       10     4
# Himachal Pradesh               1     2
# Jammu and Kashmir              3    10
# Jharkhand                      4     2
# Karnataka                    144   357
# Kerala                        53   122
# Ladakh                         1     5
# Madhya Pradesh                 8    17
# Maharashtra                   31    47
# Manipur                        1     0
# Meghalaya                      0     1
# Mizoram                        0     1
# Odisha                        18    54
# ...

# %%
df = pd.read_csv('IndividualDetails.csv')

# %%
df.dtypes
# Out:
# id                     int64
# government_id         object
# diagnosed_date        object
# age                   object
# gender                object
# detected_city         object
# detected_district     object
# detected_state        object
# nationality           object
# current_status        object
# status_change_date    object
# notes                 object
# dtype: object

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# %%
df = df.dropna(subset=['age'])

# %%
filtered_df = df[
    (df['age'] == 19) &
    (df['detected_state'].str.lower() == 'kerala')
]

filtered_df
# Out:
#         id government_id diagnosed_date   age gender detected_city  \
# 4501  4502           NaN     06-04-2020  19.0      F      Pandalam
# 6281  6282           NaN     09-04-2020  19.0      M           NaN
#
#      detected_district detected_state nationality current_status  \
# 4501    Pathanamthitta         Kerala         NaN   Hospitalized
# 6281         Kasaragod         Kerala       India   Hospitalized
#
#      status_change_date                                              notes
# 4501         06-04-2020  Student, Travelled from Delhi in Mangala Laksh...
# 6281         09-04-2020  Contact transmission. son of another confimed ...

# %%
filtered_df = df[
    (df['age'] == 18) &
    (df['detected_state'].str.lower() == 'karnataka')
]

filtered_df
# Out:
#           id government_id diagnosed_date   age gender detected_city  \
# 857      857        KA-P63     27-03-2020  18.0      M     Davangere
# 916      916        KA-P73     28-03-2020  18.0      M  Gauribidanur
# 9258    9259       KA-P239     13-04-2020  18.0      M     Malavalli
# 13638  13639       KA-P328     17-04-2020  18.0      M           NaN
# 18846  18847       KA-P410     21-04-2020  18.0      F           NaN
# 18851  18852       KA-P415     21-04-2020  18.0      F           NaN
# 24663  24664       KA-P488     25-04-2020  18.0      M           NaN
#
#       detected_district detected_state nationality current_status  \
# 857          Davanagere      Karnataka       India      Recovered
# 916         Other State      Karnataka       India      Recovered
# 9258             Mandya      Karnataka       India   Hospitalized
# 13638             Bidar      Karnataka         NaN   Hospitalized
# 18846        Vijayapura      Karnataka       India   Hospitalized
# ...
